# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("ceidg_data_surv.csv", encoding="utf-8")
raw_data = data
data.head()
# Out:
#        Status  YearOfStartingOfTheBusiness DateOfStartingOfTheBusiness  \
# 0     Aktywny                         2011                  2011-10-12
# 1  Wykreślony                         2011                  2011-01-01
# 2  Wykreślony                         2011                  2011-06-01
# 3  Wykreślony                         2011                  2011-12-15
# 4  Wykreślony                         2011                  2011-02-01
#
#   DateOfTermination  Terminated  DurationOfExistenceInMonths  \
# 0               NaN           0                           98
# 1        2015-08-06           1                           55
# 2        2017-06-29           1                           72
# 3        2014-12-19           1                           36
# 4        2012-03-06           1                           13
#
#   MainAddressVoivodeship MainAddressCounty  MainAddressTERC  \
# 0           DOLNOŚLĄSKIE        WROCłAWSKI         223052.0
# 1            MAZOWIECKIE          WARSZAWA        1465078.0
# 2            MAZOWIECKIE          WARSZAWA        1465011.0
# 3            MAZOWIECKIE          WARSZAWA        1465078.0
# 4            MAZOWIECKIE          WARSZAWA        1465108.0
#
#   CorrespondenceAddressVoivodeship  ... HasPolishCitizenship  \
# 0                     DOLNOŚLĄSKIE  ...                 True
# 1                      MAZOWIECKIE  ...                 True
# 2                      MAZOWIECKIE  ...                 True
# 3                      MAZOWIECKIE  ...                 True
# 4                      MAZOWIECKIE  ...                 True
#
#    ShareholderInOtherCompanies  PKDMainSection  PKDMainDivision  PKDMainGroup  \
# 0                        False               M             70.0         702.0
# 1                        False               F             43.0         432.0
# 2                        False               Q             86.0         862.0
# 3                        False               F             43.0         432.0
# 4                        False               G             47.0         479.0
#
#    PKDMainClass  NoOfUniquePKDSections NoOfUniquePKDDivsions  \
# 0        7022.0                      2                     3
# 1        4322.0                      1                     1
# 2        8623.0                      1                     1
# 3        4321.0                      2                     2
# 4        4791.0                      2                     3
#
#    NoOfUniquePKDGroups  NoOfUniquePKDClasses
# 0                    5                     6
# 1                    1                     1
# 2                    2                     2
# 3                    2                     2
# 4                    5                     7
#
# [5 rows x 31 columns]

# %%
data.columns.tolist()
# Out:
# ['Status',
#  'YearOfStartingOfTheBusiness',
#  'DateOfStartingOfTheBusiness',
#  'DateOfTermination',
#  'Terminated',
#  'DurationOfExistenceInMonths',
#  'MainAddressVoivodeship',
#  'MainAddressCounty',
#  'MainAddressTERC',
#  'CorrespondenceAddressVoivodeship',
#  'CorrespondenceAddressCounty',
#  'CorrespondenceAddressTERC',
#  'MainAndCorrespondenceAreTheSame',
#  'NoOfAdditionalPlaceOfTheBusiness',
#  'IsPhoneNo',
#  'IsEmail',
#  'IsWWW',
#  'CommunityProperty',
#  'HasLicences',
#  'NoOfLicences',
#  'Sex',
#  'HasPolishCitizenship',
#  'ShareholderInOtherCompanies',
#  'PKDMainSection',
#  'PKDMainDivision',
#  'PKDMainGroup',
#  'PKDMainClass',
#  'NoOfUniquePKDSections',
#  'NoOfUniquePKDDivsions',
#  'NoOfUniquePKDGroups',
#  'NoOfUniquePKDClasses']

# %%
data = data[[
    'DateOfTermination',
    'Terminated',
    'DurationOfExistenceInMonths',
    'MainAddressVoivodeship',
    'PKDMainSection',
    'PKDMainDivision',
]]

data.head()
# Out:
#   DateOfTermination  Terminated  DurationOfExistenceInMonths  \
# 0               NaN           0                           98
# 1        2015-08-06           1                           55
# 2        2017-06-29           1                           72
# 3        2014-12-19           1                           36
# 4        2012-03-06           1                           13
#
#   MainAddressVoivodeship PKDMainSection  PKDMainDivision
# 0           DOLNOŚLĄSKIE              M             70.0
# 1            MAZOWIECKIE              F             43.0
# 2            MAZOWIECKIE              Q             86.0
# 3            MAZOWIECKIE              F             43.0
# 4            MAZOWIECKIE              G             47.0

# %%
for v in np.sort(data['MainAddressVoivodeship'].astype(str).unique()): print(v)
# Out:
# BRAńSZCZYK
# BRZOZÓW
# CHODZIEŻ
# CZERSK
# CZŁUCHÓW
# DESZCZNO
# DOLNOSLąSKIE
# DOLNOŚLĄSKIE
# DOLNOśLąSKIE
# GORZÓW WLKP.
# HAJNWKA
# KOBYLANKA
# KRAKÓW
# KUJ POMORSKIE
# KUJAWSKO-POMORSKIE
# KUJAWSKOPOMORSKIE
# KWIDZYN
# LUBELSKIE
# LUBUSKIE
# MALOPOLSKIE
# MAZOPWIECKIE
# MAZOWIECKIE
# MAŁOPLSKIE
# MAŁOPOLSKA
# MAŁOPOLSKIE
# MAłOPOLSKIE
# MIELNO
# MIłOSłAW
# OPALENICA
# OPOLSKIE
# PODKARPACKIE
# PODLASKIE
# POLANICA-ZDRóJ
# POLSKA
# POMORSKI
# POMORSKIE
# RZEPIENNIK STRZYżEWSKI
# SANOK
# SKOKI
# SOCHACZEW
# STARGARD SZCZECIŃSKI
# SWIĘTOKTRZYSKIE
# SZAMOCIN
# SZCZECIN
# TOLKMICKO
# WARM-MAZ
# WARMIŃSKO-MAZURSKIE
# WARMIńSKO-MAZURSKIE
# WARMIńSKO-MAZURSKIEGO
# WARMI�SKO-MAZURSKIE
# WIELKOPOLSKA
# WIELKOPOLSKI
# WIELKOPOLSKIE
# WIELSKOPOLSKIE
# ZACHODNIOPOMORSKI
# ZACHODNIOPOMORSKIE
# ZACHODNO-POMORSKIE
# ZACHONDIOPOMORSKIE
# ZAGóRZ
# ZALESZANY
# nan
# ŁÓDZKIE
# ŁóDZKIE
# łODZKIE
# łÓDZKIE
# łóDZKIE
# ŚLĄSKIE
# ŚLąSKIE
# ŚWIETOKRZYSKIE
# ŚWIĘTOKRZYSKIE
# ŚWIęTOKRZYSKIE
# śLASKIE
# śLąSKIE
# śWIęTOKRZYSKIE

# %%
data['MainAddressVoivodeship'] = data['MainAddressVoivodeship'].str\
    .lower()\
    .replace('ą', 'a', regex=True)\
    .replace('ć', 'c', regex=True)\
    .replace('ę', 'e', regex=True)\
    .replace('ł', 'l', regex=True)\
    .replace('ń', 'n', regex=True)\
    .replace('ó', 'o', regex=True)\
    .replace('ś', 's', regex=True)\
    .replace('ź', 'z', regex=True)\
    .replace('ż', 'z', regex=True)

for v in np.sort(data['MainAddressVoivodeship'].astype(str).unique()): print(v)
# Out:
# branszczyk
# brzozow
# chodziez
# czersk
# czluchow
# deszczno
# dolnoslaskie
# gorzow wlkp.
# hajnwka
# kobylanka
# krakow
# kuj pomorskie
# kujawsko-pomorskie
# kujawskopomorskie
# kwidzyn
# lodzkie
# lubelskie
# lubuskie
# maloplskie
# malopolska
# malopolskie
# mazopwieckie
# mazowieckie
# mielno
# miloslaw
# nan
# opalenica
# opolskie
# podkarpackie
# podlaskie
# polanica-zdroj
# polska
# pomorski
# pomorskie
# rzepiennik strzyzewski
# sanok
# skoki
# slaskie
# sochaczew
# stargard szczecinski
# swietokrzyskie
# swietoktrzyskie
# szamocin
# szczecin
# tolkmicko
# warm-maz
# warminsko-mazurskie
# warminsko-mazurskiego
# warmi�sko-mazurskie
# wielkopolska
# wielkopolski
# wielkopolskie
# wielskopolskie
# zachodniopomorski
# zachodniopomorskie
# zachodno-pomorskie
# zachondiopomorskie
# zagorz
# zaleszany
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
data['MainAddressVoivodeship'] = data['MainAddressVoivodeship']\
.replace(['kuj pomorskie', 'kujawskopomorskie'], 'kujawsko-pomorskie')\
.replace(['maloplskie', 'malopolska'], 'malopolskie')\
.replace(['mazopwieckie'], 'mazowieckie')\
.replace(['pomorski'], 'pomorskie')\
.replace(['swietoktrzyskie'], 'swietokrzyskie')\
.replace(['warminsko-mazurskiego', 'warmi�sko-mazurskie', 'warm-maz'], 'warminsko-mazurskie')\
.replace(['wielkopolska', 'wielkopolski', 'wielskopolskie'], 'wielkopolskie')\
.replace(['zachodniopomorski', 'zachodno-pomorskie', 'zachondiopomorskie'], 'zachondiopomorskie')

for v in np.sort(data['MainAddressVoivodeship'].astype(str).unique()): print(v)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# branszczyk
# brzozow
# chodziez
# czersk
# czluchow
# deszczno
# dolnoslaskie
# gorzow wlkp.
# hajnwka
# kobylanka
# krakow
# kujawsko-pomorskie
# kwidzyn
# lodzkie
# lubelskie
# lubuskie
# malopolskie
# mazowieckie
# mielno
# miloslaw
# nan
# opalenica
# opolskie
# podkarpackie
# podlaskie
# polanica-zdroj
# polska
# pomorskie
# rzepiennik strzyzewski
# sanok
# skoki
# slaskie
# sochaczew
# stargard szczecinski
# swietokrzyskie
# szamocin
# szczecin
# tolkmicko
# warminsko-mazurskie
# wielkopolskie
# zachodniopomorskie
# zachondiopomorskie
# zagorz
# zaleszany

# %%
voivodes = ['dolnośląskie',
 'kujawsko-pomorskie',
 'lubelskie',
 'lubuskie',
 'łódzkie',
 'małopolskie',
 'mazowieckie',
 'opolskie',
 'podkarpackie',
 'podlaskie',
 'pomorskie',
 'śląskie',
 'świętokrzyskie',
 'warmińsko-mazurskie',
 'wielkopolskie',
 'zachodniopomorskie']

vdict = {
    v.replace('ą', 'a')\
    .replace('ć', 'c')\
    .replace('ę', 'e')\
    .replace('ł', 'l')\
    .replace('ń', 'n')\
    .replace('ó', 'o')\
    .replace('ś', 's')\
    .replace('ź', 'z')\
    .replace('ż', 'z') : v
    for v in voivodes
}

vdict
# Out:
# {'dolnoslaskie': 'dolnośląskie',
#  'kujawsko-pomorskie': 'kujawsko-pomorskie',
#  'lubelskie': 'lubelskie',
#  'lubuskie': 'lubuskie',
#  'lodzkie': 'łódzkie',
#  'malopolskie': 'małopolskie',
#  'mazowieckie': 'mazowieckie',
#  'opolskie': 'opolskie',
#  'podkarpackie': 'podkarpackie',
#  'podlaskie': 'podlaskie',
#  'pomorskie': 'pomorskie',
#  'slaskie': 'śląskie',
#  'swietokrzyskie': 'świętokrzyskie',
#  'warminsko-mazurskie': 'warmińsko-mazurskie',
#  'wielkopolskie': 'wielkopolskie',
#  'zachodniopomorskie': 'zachodniopomorskie'}

# %%
data['MainAddressVoivodeship'] = data['MainAddressVoivodeship'].replace(vdict)

for v in np.sort(data['MainAddressVoivodeship'].astype(str).unique()): print(v)
# Out:
# branszczyk
# brzozow
# chodziez
# czersk
# czluchow
# deszczno
# dolnośląskie
# gorzow wlkp.
# hajnwka
# kobylanka
# krakow
# kujawsko-pomorskie
# kwidzyn
# lubelskie
# lubuskie
# mazowieckie
# małopolskie
# mielno
# miloslaw
# nan
# opalenica
# opolskie
# podkarpackie
# podlaskie
# polanica-zdroj
# polska
# pomorskie
# rzepiennik strzyzewski
# sanok
# skoki
# sochaczew
# stargard szczecinski
# szamocin
# szczecin
# tolkmicko
# warmińsko-mazurskie
# wielkopolskie
# zachodniopomorskie
# zachondiopomorskie
# zagorz
# zaleszany
# łódzkie
# śląskie
# świętokrzyskie
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data['MainAddressVoivodeship'] = data[data['MainAddressVoivodeship'].isin(voivodes)]['MainAddressVoivodeship']

for v in np.sort(data['MainAddressVoivodeship'].astype(str).unique()): print(v)
# Out:
# dolnośląskie
# kujawsko-pomorskie
# lubelskie
# lubuskie
# mazowieckie
# małopolskie
# nan
# opolskie
# podkarpackie
# podlaskie
# pomorskie
# warmińsko-mazurskie
# wielkopolskie
# zachodniopomorskie
# łódzkie
# śląskie
# świętokrzyskie
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.head()
# Out:
#   DateOfTermination  Terminated  DurationOfExistenceInMonths  \
# 0               NaN           0                           98
# 1        2015-08-06           1                           55
# 2        2017-06-29           1                           72
# 3        2014-12-19           1                           36
# 4        2012-03-06           1                           13
#
#   MainAddressVoivodeship PKDMainSection  PKDMainDivision
# 0           dolnośląskie              M             70.0
# 1            mazowieckie              F             43.0
# 2            mazowieckie              Q             86.0
# 3            mazowieckie              F             43.0
# 4            mazowieckie              G             47.0

# %%
data['DateOfTermination'] = data['DateOfTermination'] .fillna('2021-01-01')

data.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#   DateOfTermination  Terminated  DurationOfExistenceInMonths  \
# 0        2021-01-01           0                           98
# 1        2015-08-06           1                           55
# 2        2017-06-29           1                           72
# 3        2014-12-19           1                           36
# 4        2012-03-06           1                           13
#
#   MainAddressVoivodeship PKDMainSection  PKDMainDivision
# 0           dolnośląskie              M             70.0
# 1            mazowieckie              F             43.0
# 2            mazowieckie              Q             86.0
# 3            mazowieckie              F             43.0
# 4            mazowieckie              G             47.0

# %%
data['DateOfTermination'] = pd.to_datetime(data['DateOfTermination'], format='%Y-%m-%d')

data['YearOfTermination'] = data['DateOfTermination'].dt.year

data.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   DateOfTermination  Terminated  DurationOfExistenceInMonths  \
# 0        2021-01-01           0                           98
# 1        2015-08-06           1                           55
# 2        2017-06-29           1                           72
# 3        2014-12-19           1                           36
# 4        2012-03-06           1                           13
#
#   MainAddressVoivodeship PKDMainSection  PKDMainDivision  YearOfTermination
# 0           dolnośląskie              M             70.0               2021
# 1            mazowieckie              F             43.0               2015
# 2            mazowieckie              Q             86.0               2017
# 3            mazowieckie              F             43.0               2014
# 4            mazowieckie              G             47.0               2012

# %%
data = data.groupby(list(data.columns)).size().reset_index()

data.head()
# Out:
#   DateOfTermination  Terminated  DurationOfExistenceInMonths  \
# 0        2011-02-21           1                            0
# 1        2011-06-01           1                            4
# 2        2011-06-20           1                            3
# 3        2011-07-01           1                            1
# 4        2011-07-01           1                            1
#
#   MainAddressVoivodeship PKDMainSection  PKDMainDivision  YearOfTermination  0
# 0               lubuskie              G             47.0               2011  1
# 1           dolnośląskie              J             62.0               2011  1
# 2               lubuskie              A              2.0               2011  1
# 3           dolnośląskie              S             96.0               2011  1
# 4     kujawsko-pomorskie              F             43.0               2011  1

# %%
data = data.rename(columns={0: 'Count'})

data.head()
# Out:
#   DateOfTermination  Terminated  DurationOfExistenceInMonths  \
# 0        2011-02-21           1                            0
# 1        2011-06-01           1                            4
# 2        2011-06-20           1                            3
# 3        2011-07-01           1                            1
# 4        2011-07-01           1                            1
#
#   MainAddressVoivodeship PKDMainSection  PKDMainDivision  YearOfTermination  \
# 0               lubuskie              G             47.0               2011
# 1           dolnośląskie              J             62.0               2011
# 2               lubuskie              A              2.0               2011
# 3           dolnośląskie              S             96.0               2011
# 4     kujawsko-pomorskie              F             43.0               2011
#
#    Count
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
print('before:', len(raw_data))
print('after:', len(data))
# Out:
# before: 287026
# after: 184244

# %%
data.to_csv('ceidg_data_formated.csv', index=False, encoding="utf-8")
